# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {"city": ["mumbai", "fremont", "tokyo"], "weather": ["humid", "cool", "dry"]}

# %%
X = pd.DataFrame(data)

# %%
X
# Out:
#       city weather
# 0   mumbai   humid
# 1  fremont    cool
# 2    tokyo     dry

# %%
Y = pd.DataFrame(data)
Y.set_index("city")
# Out:
#         weather
# city
# mumbai    humid
# fremont    cool
# tokyo       dry

# %%
movies = pd.read_csv("/Users/mahadevgaonkar/Downloads/movies-data.csv")

# %%
movies.head()
# Out:
#       id                            title  \
# 0   3947               Blue Velvet (film)
# 1   4231  Buffy the Vampire Slayer (film)
# 2   4729        Batman &amp; Robin (film)
# 3  11585              Show Me Love (film)
# 4  19055     Manufacturing Consent (film)
#
#                                                 cast  \
# 0   {{cast listing|<!-- Cast is in credits order ...
# 1   {{Cast listing|* [[Kristy Swanson]] as [[Buff...
# 2   {{div col}}* [[Arnold Schwarzenegger]] as [[V...
# 3   * [[Alexandra Dahlström]] as Elin Olsson* [[R...
# 4                                               None
#
#                                                 plot  \
# 0  <!-- Per WP:FILMPLOT  plot summaries for featu...
# 1  [[Buffy Summers]] is a cheerleader at Hemery H...
# 2  <!-- Per WP:FILMPLOT  plot summaries for featu...
# 3  Two girls  Agnes and Elin  attend school in th...
# 4  The film presents and illustrates Chomsky and ...
#
#                                               poster
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15795 entries, 0 to 15794
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       15795 non-null  int64
#  1    title   15795 non-null  object
#  2    cast    15795 non-null  object
#  3    plot    15783 non-null  object
#  4    poster  15795 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 617.1+ KB

# %%
movies = movies.set_index("id")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15795 entries, 3947 to 77268420
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0    title   15795 non-null  object
#  1    cast    15795 non-null  object
#  2    plot    15783 non-null  object
#  3    poster  15795 non-null  object
# dtypes: object(4)
# memory usage: 617.0+ KB

# %%
movies.head()
# Out:
#                                  title  \
# id
# 3947                Blue Velvet (film)
# 4231   Buffy the Vampire Slayer (film)
# 4729         Batman &amp; Robin (film)
# 11585              Show Me Love (film)
# 19055     Manufacturing Consent (film)
#
#                                                     cast  \
# id
# 3947    {{cast listing|<!-- Cast is in credits order ...
# 4231    {{Cast listing|* [[Kristy Swanson]] as [[Buff...
# 4729    {{div col}}* [[Arnold Schwarzenegger]] as [[V...
# 11585   * [[Alexandra Dahlström]] as Elin Olsson* [[R...
# 19055                                               None
#
#                                                     plot  \
# id
# 3947   <!-- Per WP:FILMPLOT  plot summaries for featu...
# 4231   [[Buffy Summers]] is a cheerleader at Hemery H...
# 4729   <!-- Per WP:FILMPLOT  plot summaries for featu...
# 11585  Two girls  Agnes and Elin  attend school in th...
# 19055  The film presents and illustrates Chomsky and ...
#
# ...

# %%
movies.describe()
# Out:
#                      title   cast                          plot  \
# count                15795  15795                         15783
# unique               15795  14033                         15406
# top     Blue Velvet (film)   None  {{noplot|date=January 2024}}
# freq                     1   1763                           102
#
#                                                    poster
# count                                               15795
# unique                                              13823
# top     https://upload.wikimedia.org/wikipedia/en/7/7f...
# freq                                                  863

# %%
books = pd.read_csv("/Users/mahadevgaonkar/Downloads/book_data.csv")

# %%
books.describe()
# Out:
#         book_rating  book_rating_count  book_review_count
# count  54301.000000       5.430100e+04        54301.00000
# mean       4.020027       4.350449e+04         2011.60218
# std        0.362100       2.126572e+05         7627.07287
# min        0.000000       0.000000e+00            0.00000
# 25%        3.830000       4.070000e+02           35.00000
# 50%        4.030000       2.811000e+03          188.00000
# 75%        4.220000       1.274500e+04          822.00000
# max        5.000000       5.588580e+06       160776.00000

# %%
books.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# ...

# %%
movies.head(10)
# Out:
#                                  title  \
# id
# 3947                Blue Velvet (film)
# 4231   Buffy the Vampire Slayer (film)
# 4729         Batman &amp; Robin (film)
# 11585              Show Me Love (film)
# 19055     Manufacturing Consent (film)
# 19715         Miss Congeniality (film)
# 20786          Mulholland Drive (film)
# 26541                  Repo Man (film)
# 28327                  Stargate (film)
# 29785                  The Rock (film)
#
#                                                     cast  \
# id
# 3947    {{cast listing|<!-- Cast is in credits order ...
# 4231    {{Cast listing|* [[Kristy Swanson]] as [[Buff...
# 4729    {{div col}}* [[Arnold Schwarzenegger]] as [[V...
# 11585   * [[Alexandra Dahlström]] as Elin Olsson* [[R...
# 19055                                               None
# 19715   {{Cast listing|* [[Sandra Bullock]] as FBI Sp...
# 20786   {{castlist|* [[Naomi Watts]] as Betty Elms/Di...
# 26541   {{Cast listing|* [[Harry Dean Stanton]] as Bu...
# ...

# %%
movies.loc[4231]
# Out:
# title                       Buffy the Vampire Slayer (film)
# cast       {{Cast listing|* [[Kristy Swanson]] as [[Buff...
# plot      [[Buffy Summers]] is a cheerleader at Hemery H...
# poster    https://upload.wikimedia.org/wikipedia/en/0/09...
# Name: 4231, dtype: object

# %%
movies.columns
# Out:
# Index([' title', ' cast', ' plot', ' poster'], dtype='object')

# %%
movies.loc[[4231, 29785]]
# Out:
#                                  title  \
# id
# 4231   Buffy the Vampire Slayer (film)
# 29785                  The Rock (film)
#
#                                                     cast  \
# id
# 4231    {{Cast listing|* [[Kristy Swanson]] as [[Buff...
# 29785   [[File:8.23.12MichaelBiehnByLuigiNovi6.jpg|th...
#
#                                                     plot  \
# id
# 4231   [[Buffy Summers]] is a cheerleader at Hemery H...
# 29785  Disillusioned [[Brigadier general (United Stat...
#
#                                                   poster
# id
# 4231   https://upload.wikimedia.org/wikipedia/en/0/09...
# 29785  https://upload.wikimedia.org/wikipedia/en/8/82...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15795 entries, 3947 to 77268420
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0    title   15795 non-null  object
#  1    cast    15795 non-null  object
#  2    plot    15783 non-null  object
#  3    poster  15795 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB

# %%
books.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# ...

# %%
books[books["book_authors"] == "Suzanne Collins"]
# Out:
#           book_authors                                          book_desc  \
# 0      Suzanne Collins  Winning will make you famous. Losing means cer...
# 190    Suzanne Collins  The extraordinary, ground breaking New York Ti...
# 262    Suzanne Collins  Sparks are igniting.Flames are spreading.And t...
# 374    Suzanne Collins  My name is Katniss Everdeen.Why am I not dead?...
# 2026   Suzanne Collins  This irresistible first novel tells the story ...
# 3295   Suzanne Collins  The third installment of New York Times bestse...
# 3422   Suzanne Collins  The stunning conclusion to the riveting Gregor...
# 4679   Suzanne Collins  Follow Gregor in the fourth enthralling advent...
# 5155   Suzanne Collins  The action and adventure continue for Gregor i...
# 6758   Suzanne Collins  Against all odds, Katniss Everdeen and Peeta M...
# 8447   Suzanne Collins  Against all odds, Katniss Everdeen has won the...
# 9306   Suzanne Collins  Katniss Everdeen has survived the Hunger Games...
# ...

# %%
books['book_rating'].sum()
# Out:
# np.float64(218291.5)

# %%
movies = pd.read_csv("/Users/mahadevgaonkar/Downloads/movies-data.csv")

# %%
books[books["book_authors"] == "Suzanne Collins"]
# Out:
#           book_authors                                          book_desc  \
# 0      Suzanne Collins  Winning will make you famous. Losing means cer...
# 190    Suzanne Collins  The extraordinary, ground breaking New York Ti...
# 262    Suzanne Collins  Sparks are igniting.Flames are spreading.And t...
# 374    Suzanne Collins  My name is Katniss Everdeen.Why am I not dead?...
# 2026   Suzanne Collins  This irresistible first novel tells the story ...
# 3295   Suzanne Collins  The third installment of New York Times bestse...
# 3422   Suzanne Collins  The stunning conclusion to the riveting Gregor...
# 4679   Suzanne Collins  Follow Gregor in the fourth enthralling advent...
# 5155   Suzanne Collins  The action and adventure continue for Gregor i...
# 6758   Suzanne Collins  Against all odds, Katniss Everdeen and Peeta M...
# 8447   Suzanne Collins  Against all odds, Katniss Everdeen has won the...
# 9306   Suzanne Collins  Katniss Everdeen has survived the Hunger Games...
# ...

# %%
books.plot(kind="hist", y=['book_rating'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
books.plot(kind="hist", y=['book_review_count'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54301 entries, 0 to 54300
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   book_authors       54301 non-null  object
#  1   book_desc          52970 non-null  object
#  2   book_edition       5453 non-null   object
#  3   book_format        52645 non-null  object
#  4   book_isbn          41435 non-null  object
#  5   book_pages         51779 non-null  object
#  6   book_rating        54301 non-null  float64
#  7   book_rating_count  54301 non-null  int64
#  8   book_review_count  54301 non-null  int64
#  9   book_title         54301 non-null  object
#  10  genres             51059 non-null  object
#  11  image_url          53618 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 5.0+ MB

# %%
grouped = books.groupby('book_authors')

# %%
print(grouped)

# %%
grouped[['book_authors', 'book_rating']].head()
# Out:
#                                             book_authors  book_rating
# 0                                        Suzanne Collins         4.33
# 1                             J.K. Rowling|Mary GrandPré         4.48
# 2                                             Harper Lee         4.27
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...         4.25
# 4                                        Stephenie Meyer         3.58
# ...                                                  ...          ...
# 54296                                      Howard Megdal         3.37
# 54297                                      Howard Megdal         3.97
# 54298                                      Howard Megdal         3.66
# 54299                             Mimi Baird|Eve Claxton         3.82
# 54300                                         Leah Price         3.58
#
# [43269 rows x 2 columns]

# %%
high_rating_books = grouped['book_rating'].mean().sort_values(ascending=False)

# %%
high_rating_books.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 27159 entries, John Deakin|Robin Muir to Debbi Dachinger|Randy Johnson
# Series name: book_rating
# Non-Null Count  Dtype
# --------------  -----
# 27159 non-null  float64
# dtypes: float64(1)
# memory usage: 424.4+ KB

# %%
high_rating_books.plot(kind='hist', y=['book_rating'])
plt.xlabel("book rating")
plt.ylabel("author count")
# Out:
# Text(0, 0.5, 'author count')

# %%
high_rating_books.head(20)
# Out:
# book_authors
# John Deakin|Robin Muir                                     5.0
# Yvonne Holthaus                                            5.0
# Terence W. Whitaker                                        5.0
# Carol Denise Mitchell                                      5.0
# Carol Denise Mitchell|Greenleaf Editing                    5.0
# Carol Denise Mitchell|Gregg Banks                          5.0
# L.E. Parker                                                5.0
# Carol Denise Simms                                         5.0
# Joe Bagnato                                                5.0
# Stephen J Cox                                              5.0
# Alicia  Rose                                               5.0
# L.C Wright                                                 5.0
# Nicky Allen                                                5.0
# Mosetta M. Penick Phillips-Cermak                          5.0
# Corissa Neil                                               5.0
# ...

# %%
books['genres'].unique()
# Out:
# array(['Young Adult|Fiction|Science Fiction|Dystopia|Fantasy|Science Fiction',
#        'Fantasy|Young Adult|Fiction',
#        'Classics|Fiction|Historical|Historical Fiction|Academic|School',
#        ..., 'Sports|Baseball|Abandoned',
#        'Nonfiction|Autobiography|Memoir|Biography|Psychology|Mental Health|Mental Illness|Health|Mental Health',
#        'Criticism|Literary Criticism|Philosophy|Theory|Literature|American|Literature|20th Century|Literature'],
#       dtype=object)

# %%
high_rating_books.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 27159 entries, John Deakin|Robin Muir to Debbi Dachinger|Randy Johnson
# Series name: book_rating
# Non-Null Count  Dtype
# --------------  -----
# 27159 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4+ MB

# %%
total_book_count = grouped['book_rating'].count().sort_values(ascending=False)

# %%
total_book_count
# Out:
# book_authors
# Stephen King                                       112
# Nora Roberts                                        95
# Agatha Christie                                     89
# Terry Pratchett                                     78
# Anonymous                                           65
#                                                   ...
# J. Michael Straczynski|Keu Cha|Christian Zanier      1
# J. Michael Straczynski|Dana Krejčová                 1
# J. Michael Straczynski|Brent Anderson|Keu Cha        1
# J. McFate                                            1
# 蘭陵笑笑生|劉本棟|繆天華                                        1
# Name: book_rating, Length: 27159, dtype: int64

# %%
book_rating = grouped['book_rating'].mean().sort_values(ascending=False)

# %%
book_rating
# Out:
# book_authors
# John Deakin|Robin Muir                     5.0
# Yvonne Holthaus                            5.0
# Terence W. Whitaker                        5.0
# Carol Denise Mitchell                      5.0
# Carol Denise Mitchell|Greenleaf Editing    5.0
#                                           ...
# Benjamin N.Nweke                           0.0
# B Guru                                     0.0
# Renora Licata|Licata                       0.0
# Beatriz Scaglia                            0.0
# Debbi Dachinger|Randy Johnson              0.0
# Name: book_rating, Length: 27159, dtype: float64

# %%
merged_df = pd.merge(total_book_count, book_rating, on='book_authors')

# %%
merged_df
# Out:
#                                                  book_rating_x  book_rating_y
# book_authors
# Stephen King                                               112       4.063482
# Nora Roberts                                                95       4.085895
# Agatha Christie                                             89       3.947978
# Terry Pratchett                                             78       4.106154
# Anonymous                                                   65       4.321846
# ...                                                        ...            ...
# J. Michael Straczynski|Keu Cha|Christian Zanier              1       4.110000
# J. Michael Straczynski|Dana Krejčová                         1       4.070000
# J. Michael Straczynski|Brent Anderson|Keu Cha                1       4.320000
# J. McFate                                                    1       3.500000
# 蘭陵笑笑生|劉本棟|繆天華                                                1       3.950000
#
# ...

# %%
merged_df.columns = ['total_books', 'book_rating']

# %%
final_df = merged_df.sort_values(by=['book_rating', 'total_books'], ascending=False)

# %%
final_df.head(10)
# Out:
#                                          total_books  book_rating
# book_authors
# Έκτωρ Κακναβάτος|Ektor Kaknavatos                  9          5.0
# Lucio Agustine Rosenkreutz Crăciunescu             8          5.0
# Denise Marie Mari                                  6          5.0
# Carol Denise Mitchell                              3          5.0
# Violet Plum                                        3          5.0
# Nadine   May                                       3          5.0
# Zoe Jasmine                                        3          5.0
# Dr. Van                                            3          5.0
# Alice Batchelor Hambright                          3          5.0
# Creative Success Coach, Nkosi N. Guduza            3          5.0

# %%
final_df.head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='book_authors'>
